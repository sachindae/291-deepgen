# %%
# %cd /content/drive/MyDrive/00.Classes/CSE291_DGM/Project/Lyrics2Melody/Lyrics-Conditioned-Neural-Melody-Generation
# Out:
# /content/drive/MyDrive/00.Classes/CSE291_DGM/Project/Lyrics2Melody/Lyrics-Conditioned-Neural-Melody-Generation

# %%
# !ls
# Out:
# '0. Create train-test-valid datasets.ipynb'
# '3. Melody generation using test data.ipynb'
# '4. Create song.ipynb'
#  data
#  enc_models
#  lmd-full_and_reddit_MIDI_dataset
#  lmd-full_MIDI_dataset
#  lstm-gan-lyrics2melody.py
#  melodies_experiments.zip
#  midi_statistics.py
#  mmd.py
#  __pycache__
#  Readme
#  README.md
#  roll.py
#  Skip-gram_lyric_encoders
#  Skip-gram_model_script_to_extract_syllables_and_word_level_embeddings.ipynb
#  utils.py

# %%
# !pip install pretty_midi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.6 MB 23.9 MB/s
# ...
#      |████████████████████████████████| 51 kB 8.3 MB/s
# ...
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591955 sha256=05153138e0cbf04057ac29b5c02196c5599169967a227c56687f0fb243e9c98c
#   Stored in directory: /root/.cache/pip/wheels/ad/74/7c/a06473ca8dcb63efb98c1e67667ce39d52100f837835ea18fa
# Successfully built pretty-midi
# ...

# %%
# !pip install py_midi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 90 kB 9.8 MB/s
# ...

# %%
# !python lstm-gan-lyrics2melody-v2.py --settings_file settings
# Out:
# Streaming output truncated to the last 5000 lines.
# Average song length: 60.0
# [array([68.  ,  0.75,  2.  ]), array([72.,  1.,  2.]), array([74. ,  1.5,  2. ]), array([75.,  1.,  2.]), array([77.,  1.,  2.]), array([72.,  1.,  2.]), array([74.,  1.,  2.]), array([75.,  1.,  2.]), array([72.,  1.,  2.]), array([75.,  1.,  2.]), array([80. ,  1.5,  2. ]), array([70.,  1.,  2.]), array([77. ,  1.5,  2. ]), array([70.,  1.,  2.]), array([72.,  1.,  2.]), array([75.,  1.,  2.]), array([72.,  1.,  2.]), array([74.  ,  0.75,  2.  ]), array([77.,  1.,  2.]), array([75.,  1.,  2.])]
# ML scale estimate: C natural_minor: 1.00
# Min tone: G# 4.0
# Max tone: G# 5.0
# Span: 12.0 tones
# Unique tones: 7
# Repetitions of len 2: 5
# Repetitions of len 3: 1
# Repetitions of len 4: 0
# Repetitions of len 5: 0
# Repetitions of len 6: 0
# Repetitions of len 7: 0
# Repetitions of len 8: 0
# Repetitions of len 9: 0
# Longest rest: 2.0
# Average rest: 2.0
# Number of null rests: 0
# ...

# %%
#!tf_upgrade_v2 --infile lstm-gan-lyrics2melody.py --outfile lstm-gan-lyrics2melody-v2.py
# Out:
# INFO line 19:28: Renamed 'tf.contrib.rnn.BasicLSTMCell' to 'tf.compat.v1.nn.rnn_cell.BasicLSTMCell'
# WARNING line 40:15: Using member tf.contrib.rnn.DropoutWrapper in deprecated module tf.contrib.rnn. (Manual edit required) tf.contrib.rnn.* has been deprecated, and widely used cells/functions will be moved to tensorflow/addons repository. Please check it there and file Github issues if necessary.
# ERROR line 40:15: Using member tf.contrib.rnn.DropoutWrapper in deprecated module tf.contrib. tf.contrib.rnn.DropoutWrapper cannot be converted automatically. tf.contrib will not be distributed with TensorFlow 2.0, please consider an alternative in non-contrib TensorFlow, a community-maintained repository such as tensorflow/addons, or fork the required code.
# INFO line 42:11: Renamed 'tf.contrib.rnn.MultiRNNCell' to 'tf.compat.v1.nn.rnn_cell.MultiRNNCell'
# ...
